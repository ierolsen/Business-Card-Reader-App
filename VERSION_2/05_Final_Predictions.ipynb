# %%
import cv2
import predictions as pred
import matplotlib.pyplot as plt

# %% [markdown]
# # Test 1

# %%
img = cv2.imread("data/images/54.jpg")

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 504.5, 315.5, -0.5)

# %%
img_results, entities = pred.getPredictions(img)

plt.imshow(img_results)
plt.axis("off")
# Out:
# Stanford Stanford MEDICINE Cardiovascular Institute Joseph C. Wu, MD, PhD Director, Stanford Cardiovascular Institute Professor Medicine Cardiology Radiology 265 Campus Drive, G-1120B ek 650 736-2246 Stanford, CA 94305, MC-5454 http//wulab.stanford.edu joewu@stanford.edu hetp//evistanford.edu
# (-0.5, 504.5, 315.5, -0.5)

# %%
entities
# Out:
# {'NAME': ['Joseph C Wu'],
#  'ORG': ['Stanford Medicine Cardiovascular Institute'],
#  'DES': ['Phd Director'],
#  'PHONE': ['650736'],
#  'EMAIL': ['joewu@stanford.edu'],
#  'WEB': ['http//wulab.stanford.edu', 'hetp//evistanford.edu']}

# %% [markdown]
# # Test 2

# %%
img = cv2.imread("data/images/6.jpg")

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 1064.5, 615.5, -0.5)

# %%
img_results, entities = pred.getPredictions(img)

plt.imshow(img_results)
plt.axis("off")
# Out:
# Cell 8099948528 te 8466045457 email lictsrikant@gmail.com LIFE INSURANCE CORPORATION OF INDIA seosrika ntht@gmail .com THATHINENI SRIKANTH Insurance Advisor Agent Code No. 0316164Y LIFE INSURANCE CORPORATION OF INDIA Br. Off. LIC Office, Trimulgherry, Sec’bad - 500 016. Add. Borabanda, Hyderabad - 500 018. lictsrikant8099948528.blogspot.in, interviewsinhyderabad.blogspot.in facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 Promote your business online PYBO
# (-0.5, 1064.5, 615.5, -0.5)

# %%
entities
# Out:
# {'NAME': ['Thathineni Srikanth'],
#  'ORG': ['Life Insurance Corporation Of India',
#   'Life Insurance Corporation Of India'],
#  'DES': ['Insurance Advisor'],
#  'PHONE': ['8099948528', '8466045457'],
#  'EMAIL': ['lictsrikant@gmail.com', 'seosrikantht@gmail.com'],
#  'WEB': ['interviewsinhyderabad.blogspot.in']}

# %% [markdown]
# # Test 3

# %%
img = cv2.imread("data/images/242.jpeg")

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 2439.5, 1423.5, -0.5)

# %%
img_results, entities = pred.getPredictions(img)

plt.imshow(img_results)
plt.axis("off")
# Out:
# Dr. T. S. Reddy Senior Consultant Traffic Transportation LEA Associates South Asia Pvt. Ltd. LEAdership in Consulting Engineers Planners engineering HL No 1-4-879/54/1A, Street No. 8, p lannin g Near Vijaya Bank, Lower Tank Bund, Gandhinagar, Hyderabad-500080 A.P. India solutions Tel 91-40-66747122 / 66747135 . Mobile 91-91778 82230 Email tsr@lasaindia.com ———— limmappagari@ymait.com _ ALEA Group company Website - www lasaindia.com
# (-0.5, 2439.5, 1423.5, -0.5)

# %%
entities
# Out:
# {'NAME': ['Dr T S Reddy'],
#  'ORG': ['Asia Pvt Ltd Leadership'],
#  'DES': ['Senior Consultant', 'Consulting'],
#  'PHONE': ['91', '9182230'],
#  'EMAIL': ['tsr@lasaindia.com', 'limmappagari@ymait.com'],
#  'WEB': ['wwwlasaindia.com']}
